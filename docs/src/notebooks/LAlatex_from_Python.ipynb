# %% [markdown]
# # LAlatex from Python
#
# This notebook uses `juliacall` to call Julia's `LAlatex` from a Python kernel and render the LaTeX output.

# %%
# %%julia
# using LAlatex
# A = [1 2 3; 4 5 6]
# py_show(A)
# Out:
# $\left(\begin{array}{rrr}
# 1 & 2 & 3 \\
# 4 & 5 & 6 \\
# \end{array}\right)$

# %%
from juliacall import Main as jl
jl.seval("using LAlatex")

jl.l_show("A = ", [[1, 2, 4], [3, 4, 1]]))
jl.l_show("x = ", 3, "; ", "x^2 = ", 9))
# Out:
# '$\\text{A = } \\left(\\begin{array}{r}\nSubString{String}["1", "2"] \\\\\nSubString{String}["3", "4"] \\\\\n\\end{array}\\right)$\n'
# '$\\text{x = } 3 \\text{; } \\text{x^2 = } 9$\n'
